# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# EXAMPLE OF LSTM
# https://github.com/wdomski/AISELLab

def generate_series(freq_list, offset_list, amp_list, length=100, n=1000, series=1, noise=0.2):
    t = np.linspace(0, length, n)
    data = np.zeros((n,))
    for i in range(len(freq_list)):
        freq = freq_list[i]
        offset = offset_list[i]
        amp = amp_list[i]
        data += amp * np.sin(2 * np.pi * (t - offset) * freq)
    data = data + noise * (np.random.rand(series, n) - 0.5)
    return t, data[..., np.newaxis].astype(np.float32)


def moving_window(data, window_size=25, y_size=1):
    n = data.shape[1] // (window_size + y_size)
    size = int(n * (window_size + y_size))
    reshaped = data[0, :size, 0].reshape(n, window_size + y_size, 1)
    x = reshaped[:, 0:window_size]
    y = reshaped[:, window_size:window_size + y_size]
    return x, y

input_size = 100
predicted_steps = 100
time, series = generate_series([1, 2, 10], [0, 0.3, 3], [1, 1, 0.2],
                               length=40000, n=1000000, series=1, noise=0.2)

x, y = moving_window(series, window_size=input_size, y_size=predicted_steps)

train_ind = int(len(x) * 0.8)
x_train, y_train = x[:train_ind], y[:train_ind]
x_test, y_test = x[train_ind:], y[train_ind:]
lstm_model = tf.keras.Sequential([
    tf.keras.Input(shape=(input_size, 1)),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])
lstm_model.compile(loss='mse', optimizer='adam', metrics=['mae'])

lstm_h = lstm_model.fit(x_train, y_train,
                        validation_data=(x_test, y_test),
                        epochs=10, batch_size=64)

plt.figure(figsize=(12, 6))
plt.plot(lstm_h.history['loss'], label='Training Loss', linestyle='--', color='blue')
plt.plot(lstm_h.history['val_loss'], label='Validation Loss', color='blue')
plt.plot(lstm_h.history['mae'], label='Training MAE', linestyle='--', color='green')
plt.plot(lstm_h.history['val_mae'], label='Validation MAE', color='green')
plt.title("LSTM Training History")
plt.xlabel("Epochs")
plt.ylabel("Loss / MAE")
plt.legend()
plt.show()

sample_index = 5
predicted = lstm_model.predict(x_test[sample_index:sample_index+1])[0, :, 0]
actual = y_test[sample_index, :, 0]
input_window = x_test[sample_index, :, 0]

full_predicted = np.concatenate([input_window, predicted])
full_actual = np.concatenate([input_window, actual])

plt.figure(figsize=(14, 6))
plt.plot(range(len(full_actual)), full_actual, label="Actual", linewidth=2)
plt.plot(range(len(full_predicted)), full_predicted, label="Predicted", linestyle='--')
plt.axvline(x=input_size - 1, color='gray', linestyle=':', label='Prediction Start')
plt.title("LSTM Prediction (Input Window + Predicted Future)")
plt.xlabel("Timestep")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - loss: 0.6416 - mae: 0.6344 - val_loss: 0.1130 - val_mae: 0.2720
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.1335 - mae: 0.2943 - val_loss: 0.0357 - val_mae: 0.1528
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0658 - mae: 0.2020 - val_loss: 0.0253 - val_mae: 0.1292
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0534 - mae: 0.1810 - val_loss: 0.0227 - val_mae: 0.1234
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0481 - mae: 0.1717 - val_loss: 0.0214 - val_mae: 0.1202
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0446 - mae: 0.1650 - val_loss: 0.0200 - val_mae: 0.1166
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 0.0422 - mae: 0.1602 - val_loss: 0.0183 - val_mae: 0.1121
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - loss: 0.0403 - mae: 0.1563 - val_loss: 0.0172 - val_mae: 0.1084
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0383 - mae: 0.1521 - val_loss: 0.0167 - val_mae: 0.1058
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 0.0362 - mae: 0.1473 - val_loss: 0.0145 - val_mae: 0.0983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import Input

# %%
df = pd.read_csv("HomeC.csv",low_memory=False)
print(f'HomeC.csv : {df.shape}')
df.head(5)
df.tail(5)
# Out:
# HomeC.csv : (503911, 32)
#               time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 503906  1452128306  1.599333  0.003233            1.599333         0.000050
# 503907  1452128307  1.924267  0.003217            1.924267         0.000033
# 503908  1452128308  1.978200  0.003217            1.978200         0.000050
# 503909  1452128309  1.990950  0.003233            1.990950         0.000050
# 503910           \       NaN       NaN                 NaN              NaN
#
#         Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 503906        0.104017        0.625033          0.041750     0.005233
# 503907        0.422383        0.637733          0.042033     0.004983
# 503908        0.495667        0.620367          0.042100     0.005333
# 503909        0.494700        0.634133          0.042100     0.004917
# 503910             NaN             NaN               NaN          NaN
#
#         Wine cellar [kW]  ...  visibility     summary  apparentTemperature  \
# 503906          0.008433  ...        8.74  Light Rain                29.45
# 503907          0.008467  ...        8.74  Light Rain                29.45
# 503908          0.008233  ...        8.74  Light Rain                29.45
# 503909          0.008133  ...        8.74  Light Rain                29.45
# 503910               NaN  ...         NaN         NaN                  NaN
#
#         pressure  windSpeed  cloudCover  windBearing  precipIntensity  \
# 503906   1011.49       6.72        0.31        186.0           0.0101
# 503907   1011.49       6.72        0.31        186.0           0.0101
# 503908   1011.49       6.72        0.31        186.0           0.0101
# 503909   1011.49       6.72        0.31        186.0           0.0101
# 503910       NaN        NaN         NaN          NaN              NaN
#
#         dewPoint  precipProbability
# 503906     31.27               0.51
# 503907     31.27               0.51
# 503908     31.27               0.51
# 503909     31.27               0.51
# 503910       NaN                NaN
#
# [5 rows x 32 columns]

# %%
# last row is nullptr therefore needs to be removed...
df = df[0:-1]

# %%
df.columns
# Out:
# Index(['time', 'use [kW]', 'gen [kW]', 'House overall [kW]', 'Dishwasher [kW]',
#        'Furnace 1 [kW]', 'Furnace 2 [kW]', 'Home office [kW]', 'Fridge [kW]',
#        'Wine cellar [kW]', 'Garage door [kW]', 'Kitchen 12 [kW]',
#        'Kitchen 14 [kW]', 'Kitchen 38 [kW]', 'Barn [kW]', 'Well [kW]',
#        'Microwave [kW]', 'Living room [kW]', 'Solar [kW]', 'temperature',
#        'icon', 'humidity', 'visibility', 'summary', 'apparentTemperature',
#        'pressure', 'windSpeed', 'cloudCover', 'windBearing', 'precipIntensity',
#        'dewPoint', 'precipProbability'],
#       dtype='object')

# %%
# as disucussed, its would be probably be better to convert time into hours and go from there...
# but first need to fix the unix type format and some nan error in time
df['time'] = pd.to_numeric(df['time'], errors='coerce')
df = df.dropna(subset=['time'])
df['time'] = pd.to_datetime(df['time'], unit='s')

# %%
df.head(5)
# Out:
#                  time  use [kW]  gen [kW]  House overall [kW]  \
# 0 2016-01-01 05:00:00  0.932833  0.003483            0.932833
# 1 2016-01-01 05:00:01  0.934333  0.003467            0.934333
# 2 2016-01-01 05:00:02  0.931817  0.003467            0.931817
# 3 2016-01-01 05:00:03  1.022050  0.003483            1.022050
# 4 2016-01-01 05:00:04  1.139400  0.003467            1.139400
#
#    Dishwasher [kW]  Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  \
# 0         0.000033        0.020700        0.061917          0.442633
# 1         0.000000        0.020717        0.063817          0.444067
# 2         0.000017        0.020700        0.062317          0.446067
# 3         0.000017        0.106900        0.068517          0.446583
# 4         0.000133        0.236933        0.063983          0.446533
#
#    Fridge [kW]  Wine cellar [kW]  ...  visibility  summary  \
# 0     0.124150          0.006983  ...        10.0    Clear
# 1     0.124000          0.006983  ...        10.0    Clear
# 2     0.123533          0.006983  ...        10.0    Clear
# 3     0.123133          0.006983  ...        10.0    Clear
# 4     0.122850          0.006850  ...        10.0    Clear
#
#    apparentTemperature  pressure  windSpeed  cloudCover  windBearing  \
# 0                29.26   1016.91       9.18  cloudCover          282
# 1                29.26   1016.91       9.18  cloudCover          282
# 2                29.26   1016.91       9.18  cloudCover          282
# 3                29.26   1016.91       9.18  cloudCover          282
# 4                29.26   1016.91       9.18  cloudCover          282
#
#    precipIntensity  dewPoint  precipProbability
# 0              0.0      24.4                0.0
# 1              0.0      24.4                0.0
# 2              0.0      24.4                0.0
# 3              0.0      24.4                0.0
# 4              0.0      24.4                0.0
#
# [5 rows x 32 columns]

# %%
df['time'] = pd.DatetimeIndex(pd.date_range('2016-01-01 05:00', periods=len(df),  freq='min'))
df.head(3)
# Out:
#                  time  use [kW]  gen [kW]  House overall [kW]  \
# 0 2016-01-01 05:00:00  0.932833  0.003483            0.932833
# 1 2016-01-01 05:01:00  0.934333  0.003467            0.934333
# 2 2016-01-01 05:02:00  0.931817  0.003467            0.931817
#
#    Dishwasher [kW]  Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  \
# 0         0.000033        0.020700        0.061917          0.442633
# 1         0.000000        0.020717        0.063817          0.444067
# 2         0.000017        0.020700        0.062317          0.446067
#
#    Fridge [kW]  Wine cellar [kW]  ...  visibility  summary  \
# 0     0.124150          0.006983  ...        10.0    Clear
# 1     0.124000          0.006983  ...        10.0    Clear
# 2     0.123533          0.006983  ...        10.0    Clear
#
#    apparentTemperature  pressure  windSpeed  cloudCover  windBearing  \
# 0                29.26   1016.91       9.18  cloudCover        282.0
# 1                29.26   1016.91       9.18  cloudCover        282.0
# 2                29.26   1016.91       9.18  cloudCover        282.0
#
#    precipIntensity  dewPoint  precipProbability
# 0              0.0      24.4                0.0
# 1              0.0      24.4                0.0
# 2              0.0      24.4                0.0
#
# [3 rows x 32 columns]

# %%
# resampling for an hour...
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)
hourly_df = df['House overall [kW]'].resample('h').mean().reset_index()

# %%
# need to do normalization to avoid exploding/vanishing gradients

scaler = MinMaxScaler()
scaled = scaler.fit_transform(hourly_df[['House overall [kW]']])

# %%
# 80/10/10

# input=12 hours of past data
# forecast= 3 hours
# jump 15 horus

total = len(scaled)
train_end = int(0.8 * total)
val_end = int(0.9 * total)

train_data = scaled[:train_end]
val_data = scaled[train_end:val_end]
test_data = scaled[val_end:]

def sequences(data, input_len=12, forecast_len=3, jump=15):
    X, y = [], []
    for i in range(0, len(data) - input_len - forecast_len + 1, jump):
        X.append(data[i:i+input_len])
        y.append(data[i+input_len:i+input_len+forecast_len].flatten())
    return np.array(X), np.array(y)

input_len = 12
forecast_len = 3
jump = 15

X_train, y_train = sequences(train_data, input_len, forecast_len, jump)
X_val, y_val = sequences(val_data, input_len, forecast_len, jump)
X_test, y_test = sequences(test_data, input_len, forecast_len, jump)

# %%
model = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(64),
    Dense(3)
])

model.compile(optimizer='adam', loss='mse')

history = model.fit(
    X_train, y_train,
    epochs=100,
    validation_data=(X_val, y_val)
)

predictions = model.predict(X_test)
predicted_kW = scaler.inverse_transform(predictions)
actual_kW = scaler.inverse_transform(y_test)
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0145 - val_loss: 0.0033
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - val_loss: 0.0022
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0100 - val_loss: 0.0020
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0058 - val_loss: 0.0020
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0081 - val_loss: 0.0020
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086 - val_loss: 0.0019
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0067 - val_loss: 0.0019
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - val_loss: 0.0018
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0057 - val_loss: 0.0018
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0061 - val_loss: 0.0017
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0067 - val_loss: 0.0017
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0064 - val_loss: 0.0017
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0058 - val_loss: 0.0017
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0047 - val_loss: 0.0017
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step

# %%
plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Val Loss (MSE)', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training v Validation loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
flat_pred = predicted_kW.flatten()
flat_actual = actual_kW.flatten()

plt.figure(figsize=(16, 5))
plt.plot(flat_actual, label='Actual', linewidth=2)
plt.plot(flat_pred, label='Predicted', linestyle='--', linewidth=1.5)
plt.title('Test Set')
plt.xlabel('3hour forecasts')
plt.ylabel('House overall [kW]')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
